# %% [markdown]
# <a href="https://colab.research.google.com/github/imorales87/IST718-Lab1/blob/main/Copy_of_Lab2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
df = pd.read_csv('https://raw.githubusercontent.com/2SUBDA/IST_718/master/Zip_Zhvi_SingleFamilyResidence_20.csv', on_bad_lines='skip')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from math import sqrt
from statsmodels.tsa.arima_model import ARIMA
import datetime
from statsmodels.tsa.stattools import adfuller
from sklearn.metrics import mean_squared_error
from pandas import DataFrame
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
import seaborn as sns
from statsmodels.tsa.stattools import acf, pacf
import matplotlib as mpl
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
from statsmodels.graphics import tsaplots as tsaplots
from dateutil.relativedelta import relativedelta
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from math import sqrt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
#eliminate duplicates 
df.duplicated(subset=None, keep='first')
df.duplicated(keep='last')
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15403    False
# 15404    False
# 15405    False
# 15406    False
# 15407    False
# Length: 15408, dtype: bool

# %%
df.duplicated(keep=False)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 15403    False
# 15404    False
# 15405    False
# 15406    False
# 15407    False
# Length: 15408, dtype: bool

# %%
#drop N/a values 
df.dropna()
# Out:
#        RegionID  SizeRank  RegionName RegionType StateName State  \
# 0         77207     10323       44502        Zip        OH    OH
# 1         89222     30742       71839        Zip        AR    AR
# 2         63200     31386       13639        Zip        NY    NY
# 3         76354     21359       42410        Zip        KY    KY
# 7         68784     32559       25849        Zip        WV    WV
# ...         ...       ...         ...        ...       ...   ...
# 15396     68625      8233       25504        Zip        WV    WV
# 15398     73125      8236       34479        Zip        FL    FL
# 15399     87515      8236       67220        Zip        KS    KS
# 15402     95251      8243       87015        Zip        NM    NM
# 15404     69667      8246       28021        Zip        NC    NC
#
#                 City                       Metro             CountyName  \
# 0         Youngstown  Youngstown-Warren-Boardman        Mahoning County
# ...

# %%
df
# Out:
#        RegionID  SizeRank  RegionName  ... 1/31/2020 2/29/2020 3/31/2020
# 0         77207     10323       44502  ...     20572     20821     21178
# 1         89222     30742       71839  ...     21590     21514     21485
# 2         63200     31386       13639  ...     43832     44111     44222
# 3         76354     21359       42410  ...     28008     27840     27657
# 7         68784     32559       25849  ...     27644     27825     27888
# ...         ...       ...         ...  ...       ...       ...       ...
# 15396     68625      8233       25504  ...    137427    137601    137734
# 15398     73125      8236       34479  ...    141369    141720    142162
# 15399     87515      8236       67220  ...    166538    167892    169281
# 15402     95251      8243       87015  ...    261942    262560    263152
# 15404     69667      8246       28021  ...    146951    147997    148544
#
# [12757 rows x 252 columns]

# %%
df.dropna(axis='columns')
# Out:
#        RegionID  SizeRank  RegionName  ... 1/31/2020 2/29/2020 3/31/2020
# 0         77207     10323       44502  ...     20572     20821     21178
# 1         89222     30742       71839  ...     21590     21514     21485
# 2         63200     31386       13639  ...     43832     44111     44222
# 3         76354     21359       42410  ...     28008     27840     27657
# 7         68784     32559       25849  ...     27644     27825     27888
# ...         ...       ...         ...  ...       ...       ...       ...
# 15396     68625      8233       25504  ...    137427    137601    137734
# 15398     73125      8236       34479  ...    141369    141720    142162
# 15399     87515      8236       67220  ...    166538    167892    169281
# 15402     95251      8243       87015  ...    261942    262560    263152
# 15404     69667      8246       28021  ...    146951    147997    148544
#
# [12757 rows x 252 columns]

# %%
df.dropna(how='all')
# Out:
#        RegionID  SizeRank  RegionName  ... 1/31/2020 2/29/2020 3/31/2020
# 0         77207     10323       44502  ...     20572     20821     21178
# 1         89222     30742       71839  ...     21590     21514     21485
# 2         63200     31386       13639  ...     43832     44111     44222
# 3         76354     21359       42410  ...     28008     27840     27657
# 7         68784     32559       25849  ...     27644     27825     27888
# ...         ...       ...         ...  ...       ...       ...       ...
# 15396     68625      8233       25504  ...    137427    137601    137734
# 15398     73125      8236       34479  ...    141369    141720    142162
# 15399     87515      8236       67220  ...    166538    167892    169281
# 15402     95251      8243       87015  ...    261942    262560    263152
# 15404     69667      8246       28021  ...    146951    147997    148544
#
# [12757 rows x 252 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 12757 entries, 0 to 15404
# Columns: 252 entries, RegionID to 3/31/2020
# dtypes: float64(216), int64(30), object(6)
# memory usage: 24.6+ MB

# %%
df.dropna(inplace=True)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    RegionID  SizeRank  RegionName RegionType StateName State          City  \
# 0     77207     10323       44502        Zip        OH    OH    Youngstown
# 1     89222     30742       71839        Zip        AR    AR       Garland
# 2     63200     31386       13639        Zip        NY    NY  Town Of Fine
# 3     76354     21359       42410        Zip        KY    KY    Earlington
# 7     68784     32559       25849        Zip        WV    WV        Lester
#
#                         Metro             CountyName  1/31/2000  2/29/2000  \
# 0  Youngstown-Warren-Boardman        Mahoning County      11209      11125
# 1                   Texarkana          Miller County      15746      15751
# 2          Ogdensburg-Massena  Saint Lawrence County      23529      23924
# 3                Madisonville         Hopkins County      14205      14201
# 7                     Beckley         Raleigh County      16883      16994
#
# ...

# %%
#replace special characters 
df = df.replace('^\s*$',np.nan, regex = True)

# %%
df.isnull().sum()
# Out:
# RegionID      0
# SizeRank      0
# RegionName    0
# RegionType    0
# StateName     0
#              ..
# 11/30/2019    0
# 12/31/2019    0
# 1/31/2020     0
# 2/29/2020     0
# 3/31/2020     0
# Length: 252, dtype: int64

# %%
pd.set_option('display.float_format', lambda x: '%.5f' % x)
pd.set_option('display.float_format','{:.0f}'.format)

# %%
df.dropna(axis = 0 ,inplace = True)

# %%
df.isnull().sum()
df1 = df.drop(['RegionID','RegionType', 'StateName'], axis=1)
df1.head()
# Out:
#    SizeRank  RegionName State          City                       Metro  \
# 0     10323       44502    OH    Youngstown  Youngstown-Warren-Boardman
# 1     30742       71839    AR       Garland                   Texarkana
# 2     31386       13639    NY  Town Of Fine          Ogdensburg-Massena
# 3     21359       42410    KY    Earlington                Madisonville
# 7     32559       25849    WV        Lester                     Beckley
#
#               CountyName  1/31/2000  2/29/2000  3/31/2000  4/30/2000  \
# 0        Mahoning County      11209      11125      11172      11133
# 1          Miller County      15746      15751      15821      16075
# 2  Saint Lawrence County      23529      23924      24016      24329
# 3         Hopkins County      14205      14201      14327      14368
# 7         Raleigh County      16883      16994      17098      17086
#
#    5/31/2000  6/30/2000  7/31/2000  8/31/2000  9/30/2000  10/31/2000  \
# ...

# %%
df.ar = df1[df1['State'] == 'AR']
df.ar.head()
# Out:
# <ipython-input-622-7a5af1a54d76>:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.ar = df1[df1['State'] == 'AR']
#     SizeRank  RegionName State        City         Metro  \
# 1      30742       71839    AR     Garland     Texarkana
# 13     25332       71644    AR       Grady    Pine Bluff
# 17     28821       72359    AR     Madison  Forrest City
# 33      7784       71601    AR  Pine Bluff    Pine Bluff
# 61     30679       72139    AR     Russell        Searcy
#
#               CountyName  1/31/2000  2/29/2000  3/31/2000  4/30/2000  \
# 1          Miller County      15746      15751      15821      16075
# 13        Lincoln County      19468      19540      19655      19917
# 17  Saint Francis County      18713      18249      18096      18226
# 33      Jefferson County      20497      20635      20720      20836
# ...

# %%
metroar = df.ar.loc[df.ar['Metro'].isin(['Searcy', 'Little Rock-North Little Rock-Conway', 'Fayetteville-Springdale-Rogers', 'Hot Springs'])]

# %%
metroar
# Out:
#        SizeRank  RegionName State               City  \
# 61        30679       72139    AR            Russell
# 209        8043       72114    AR  North Little Rock
# 259       27759       72001    AR              Adona
# 426       19004       72070    AR            Houston
# 476        8519       72150    AR           Sheridan
# ...         ...         ...   ...                ...
# 8735      13101       72732    AR           Garfield
# 9183      14554       72718    AR       Cave Springs
# 10408      8690       72212    AR        Little Rock
# 10472     22038       72122    AR              Paron
# 11857      4019       72223    AR        Little Rock
#
#                                       Metro      CountyName  1/31/2000  \
# 61                                   Searcy    White County      25008
# 209    Little Rock-North Little Rock-Conway  Pulaski County      32389
# 259    Little Rock-North Little Rock-Conway    Perry County      40037
# ...

# %%
keep_cols = ['RegionName', 'Metro']

# %%
dropyears= ['2018']

# %%
Dates = ['1/31/2000', '2/29/2000', '3/31/2000', '4/30/2000', '5/31/2000', '6/30/2000', '7/31/2000', '8/31/2000', '9/30/2000', '10/31/2000', '11/30/2000', '12/31/2000', '1/31/2001',  '2/28/2001',  '3/31/2001',  '4/30/2001',  '5/31/2001',  '6/30/2001',  '7/31/2001',  '8/31/2001', '9/30/2001', '10/31/2001', '11/30/2001', '12/31/2001', '1/31/2002',  '2/28/2002',  '3/31/2002',  '4/30/2002',  '5/31/2002',  '6/30/2002',  '7/31/2002',  '8/31/2002',  '9/30/2002',  '10/31/2002', '11/30/2002', '12/31/2002', '1/31/2003',  '2/28/2003','3/31/2003', '4/30/2003', '5/31/2003',  '6/30/2003', '7/31/2003', '8/31/2003',  '9/30/2003',  '10/31/2003', '11/30/2003', '12/31/2003', '1/31/2004',  '2/29/2004',  '3/31/2004',  '4/30/2004', '5/31/2004', '6/30/2004',  '7/31/2004', '8/31/2004', '9/30/2004',  '10/31/2004', '11/30/2004', '12/31/2004', '1/31/2005',  '2/28/2005',  '3/31/2005',  '4/30/2005',  '5/31/2005',  '6/30/2005',  '7/31/2005',  '8/31/2005',  '9/30/2005',  '10/31/2005', '11/30/2005', '12/31/2005', '1/31/2006', '2/28/2006', '3/31/2006', '4/30/2006', '5/31/2006',  '6/30/2006', '7/31/2006', '8/31/2006', '9/30/2006', '10/31/2006', '11/30/2006', '12/31/2006', '1/31/2007',  '2/28/2007',  '3/31/2007',  '4/30/2007',  '5/31/2007', '6/30/2007', '7/31/2007', '8/31/2007', '9/30/2007', '10/31/2007', '11/30/2007', '12/31/2007', '1/31/2008', '2/29/2008', '3/31/2008', '4/30/2008', '5/31/2008', '6/30/2008', '7/31/2008', '8/31/2008', '9/30/2008', '10/31/2008', '11/30/2008', '12/31/2008', '1/31/2009', '2/28/2009', '3/31/2009', '4/30/2009', '5/31/2009', '6/30/2009', '7/31/2009', '8/31/2009', '9/30/2009', '10/31/2009', '11/30/2009', '12/31/2009', '1/31/2010', '2/28/2010', '3/31/2010', '4/30/2010', '5/31/2010', '6/30/2010', '7/31/2010', '8/31/2010', '9/30/2010', '10/31/2010', '11/30/2010', '12/31/2010', '1/31/2011',  '2/28/2011',  '3/31/2011',  '4/30/2011',  '5/31/2011',  '6/30/2011',  '7/31/2011',  '8/31/2011',  '9/30/2011', '10/31/2011',  '11/30/2011', '12/31/2011', '1/31/2012',  '2/29/2012',  '3/31/2012',  '4/30/2012',  '5/31/2012',  '6/30/2012',  '7/31/2012',  '8/31/2012',  '9/30/2012',  '10/31/2012', '11/30/2012', '12/31/2012', '1/31/2013', '2/28/2013', '3/31/2013', '4/30/2013', '5/31/2013', '6/30/2013', '7/31/2013', '8/31/2013', '9/30/2013', '10/31/2013', '11/30/2013', '12/31/2013', '1/31/2014', '2/28/2014', '3/31/2014', '4/30/2014', '5/31/2014', '6/30/2014', '7/31/2014', '8/31/2014', '9/30/2014', '10/31/2014', '11/30/2014', '12/31/2014', '1/31/2015', '2/28/2015', '3/31/2015',  '4/30/2015',  '5/31/2015',  '6/30/2015',  '7/31/2015',  '8/31/2015',  '9/30/2015',  '10/31/2015', '11/30/2015', '12/31/2015', '1/31/2016',  '2/29/2016',  '3/31/2016',  '4/30/2016',  '5/31/2016',  '6/30/2016',  '7/31/2016',  '8/31/2016',  '9/30/2016',  '10/31/2016',   '11/30/2016',   '12/31/2016',   '1/31/2017',  '2/28/2017',  '3/31/2017',  '4/30/2017',  '5/31/2017',  '6/30/2017',  '7/31/2017',  '8/31/2017',  '9/30/2017',  '10/31/2017', '11/30/2017', '12/31/2017', '1/31/2019', '2/28/2019',   '3/31/2019',  '4/30/2019',  '5/31/2019',  '6/30/2019',  '7/31/2019',  '8/31/2019',  '9/30/2019',  '10/31/2019', '11/30/2019', '12/31/2019', '1/31/2020', '2/29/2020', '3/31/2020']

# %%
meltedf = pd.melt(frame=metroar, id_vars=keep_cols, value_vars=Dates, var_name='YearMonth', value_name='HousePrice')

# %%
meltedf
# Out:
#        RegionName                                 Metro  YearMonth  HousePrice
# 0           72139                                Searcy  1/31/2000       25008
# 1           72114  Little Rock-North Little Rock-Conway  1/31/2000       32389
# 2           72001  Little Rock-North Little Rock-Conway  1/31/2000       40037
# 3           72070  Little Rock-North Little Rock-Conway  1/31/2000       54299
# 4           72150  Little Rock-North Little Rock-Conway  1/31/2000       44766
# ...           ...                                   ...        ...         ...
# 21709       72732        Fayetteville-Springdale-Rogers  3/31/2020      242029
# 21710       72718        Fayetteville-Springdale-Rogers  3/31/2020      298333
# 21711       72212  Little Rock-North Little Rock-Conway  3/31/2020      285173
# 21712       72122  Little Rock-North Little Rock-Conway  3/31/2020      252909
# 21713       72223  Little Rock-North Little Rock-Conway  3/31/2020      338871
#
# ...

# %%
meltedf.dropna(inplace=True)

# %%
df_hotsprings = meltedf[meltedf['Metro'] == 'Hot Springs']
df_littlerock = meltedf[meltedf['Metro'] == 'Little Rock-North Little Rock-Conway']
df_fayetteville = meltedf[meltedf['Metro'] == 'Fayetteville-Springdale-Rogers']
df_searcy = meltedf[meltedf['Metro'] == 'Searcy']
df_ak = pd.concat([df_hotsprings, df_searcy, df_fayetteville, df_littlerock], ignore_index=True)

# %%
df_ak
# Out:
#        RegionName                                 Metro  YearMonth  HousePrice
# 0           71901                           Hot Springs  1/31/2000       62223
# 1           71949                           Hot Springs  1/31/2000       74295
# 2           71964                           Hot Springs  1/31/2000       88776
# 3           71913                           Hot Springs  1/31/2000       96315
# 4           71968                           Hot Springs  1/31/2000       98990
# ...           ...                                   ...        ...         ...
# 21709       71909  Little Rock-North Little Rock-Conway  3/31/2020      182307
# 21710       72113  Little Rock-North Little Rock-Conway  3/31/2020      217620
# 21711       72212  Little Rock-North Little Rock-Conway  3/31/2020      285173
# 21712       72122  Little Rock-North Little Rock-Conway  3/31/2020      252909
# 21713       72223  Little Rock-North Little Rock-Conway  3/31/2020      338871
#
# ...

# %%
list_Month = [i.split(" ")[0][5:7] for i in  list(df_ak['YearMonth'])]

# %%
df_ak_monthly = df_ak.groupby(['RegionName', 'Metro', 'YearMonth']).mean()

# %%
df_ak_monthly
# Out:
#                                                      HousePrice
# RegionName Metro                          YearMonth
# 71901      Hot Springs                    1/31/2000       62223
#                                           1/31/2001       66896
#                                           1/31/2002       68306
#                                           1/31/2003       70380
#                                           1/31/2004       75740
# ...                                                         ...
# 72959      Fayetteville-Springdale-Rogers 9/30/2014      114749
#                                           9/30/2015      121555
#                                           9/30/2016      116223
#                                           9/30/2017      136479
#                                           9/30/2019      149048
#
# [21714 rows x 1 columns]

# %%
df_ak_agg = pd.Series.to_frame(df_ak.groupby(by=['YearMonth','Metro'])['HousePrice'].mean())
df_ak_agg.reset_index(level=0, inplace=True)
df_ak_agg.reset_index(level=0, inplace=True)

# %%
df_ak_agg
# Out:
#                                     Metro  YearMonth  HousePrice
# 0          Fayetteville-Springdale-Rogers  1/31/2000      104083
# 1                             Hot Springs  1/31/2000       84120
# 2    Little Rock-North Little Rock-Conway  1/31/2000       95588
# 3                                  Searcy  1/31/2000       63022
# 4          Fayetteville-Springdale-Rogers  1/31/2001      109865
# ..                                    ...        ...         ...
# 919                                Searcy  9/30/2017       92270
# 920        Fayetteville-Springdale-Rogers  9/30/2019      187639
# 921                           Hot Springs  9/30/2019      142222
# 922  Little Rock-North Little Rock-Conway  9/30/2019      143365
# 923                                Searcy  9/30/2019       99069
#
# [924 rows x 3 columns]

# %%
print('All Metro Areas: ')
print(df_ak_agg.describe(include='all'))

print('\nHot Springs only:')
print(df_ak_agg[df_ak_agg['Metro'] == 'Hot Springs'].describe(include='all'))

print('\nLittle Rock only:')
print(df_ak_agg[df_ak_agg['Metro'] == 'Little Rock-North Little Rock-Conway'].describe(include='all'))

print('\nFayetteville only:')
print(df_ak_agg[df_ak_agg['Metro'] == 'Fayetteville-Springdale-Rogers'].describe(include='all'))

print('\nSearcy only:')
print(df_ak_agg[df_ak_agg['Metro'] == 'Searcy'].describe(include='all'))
# Out:
# All Metro Areas:
#                                  Metro  YearMonth  HousePrice
# count                              924        924         924
# unique                               4        231         NaN
# top     Fayetteville-Springdale-Rogers  1/31/2000         NaN
# freq                               231          4         NaN
# mean                               NaN        NaN      115115
# std                                NaN        NaN       27377
# min                                NaN        NaN       63022
# 25%                                NaN        NaN       90930
# 50%                                NaN        NaN      121538
# 75%                                NaN        NaN      131875
# max                                NaN        NaN      191862
#
# Hot Springs only:
#               Metro  YearMonth  HousePrice
# count           231        231         231
# unique            1        231         NaN
# top     Hot Springs  1/31/2000         NaN
# ...

# %%
fig1, ax1 = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=False,)
fig1.suptitle('Distribution of House Prices by AK Metro Area')
fig1.tight_layout(pad=3)

sns.distplot(df_hotsprings['HousePrice'], hist=True, bins=15, kde=False, rug=True, ax=ax1[0][0])
ax1[0][0].title.set_text('Hot Springs')
ax1[0][0].xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

sns.distplot(df_littlerock['HousePrice'], hist=True, bins=15, kde=False, rug=True, ax=ax1[0][1])
ax1[0][1].title.set_text('Little Rock')
ax1[0][1].xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

sns.distplot(df_fayetteville['HousePrice'], hist=True, bins=15, kde=False, rug=True, ax=ax1[1][0])
ax1[1][0].title.set_text('Fayetteville')
ax1[1][0].xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))

sns.distplot(df_searcy['HousePrice'], hist=True, bins=15, kde=False, rug=True, ax=ax1[1][1])
ax1[1][1].title.set_text('Searcy')
ax1[1][1].xaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-792-9090e6c540c9> in <module>
# ----> 1 fig1, ax1 = plt.subplots(nrows=2, ncols=2, sharex=False, sharey=False,)
#       2 fig1.suptitle('Distribution of House Prices by AK Metro Area')
#       3 fig1.tight_layout(pad=3)
#       4
#       5 sns.distplot(df_hotsprings['HousePrice'], hist=True, bins=15, kde=False, rug=True, ax=ax1[0][0])
#
# /usr/local/lib/python3.8/dist-packages/matplotlib/pyplot.py in subplots(nrows, ncols, sharex, sharey, squeeze, subplot_kw, gridspec_kw, **fig_kw)
#    1175
#    1176     """
# -> 1177     fig = figure(**fig_kw)
#    1178     axs = fig.subplots(nrows=nrows, ncols=ncols, sharex=sharex, sharey=sharey,
#    1179                        squeeze=squeeze, subplot_kw=subplot_kw,
#
# TypeError: 'tuple' object is not callable

# %%
plot2 = sns.lineplot(x='YearMonth', y='HousePrice', data=df_ak_agg, hue='Metro')
fig2.suptitle('House Prices over Time, AK Metro Areas')
ax2.set_ylabel('Price')
ax2.set_xlabel('Year')
ax2.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-796-c3e5acad432b> in <module>
# ----> 1 plot2 = sns.lineplot(x='YearMonth', y='HousePrice', data=df_ak_agg, hue='Metro')
#       2 fig2.suptitle('House Prices over Time, AK Metro Areas')
#       3 ax2.set_ylabel('Price')
#       4 ax2.set_xlabel('Year')
#       5 ax2.yaxis.set_major_formatter(mpl.ticker.FuncFormatter(lambda x, p: format(int(x), ',')))
#
# /usr/local/lib/python3.8/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
print(metroar.SizeRank.describe(),'\n')
# Out:
# count      94
# mean    10749
# std      7466
# min       332
# 25%      4336
# 50%      9612
# 75%     14660
# max     30679
# Name: SizeRank, dtype: float64

# %%
metro_20 = metroar.SizeRank.quantile(q=0.20)

# %%
metro_top20= metroar[metroar['SizeRank']<metro_20].drop(['City',
                                                       'State','Metro','CountyName',
                                                       'SizeRank'],axis=1)

# %%
print(f'Amount of zipcodes: {len(metro_top20)}')
# Out:
# Amount of zipcodes: 19

# %%
metro_top20['yr_avg']=metro_top20.iloc[:,-12:].mean(skipna=True, axis=1)

# %%
print(metro_top20['yr_avg'].describe(),'\n')
# Out:
# count       19
# mean    168987
# std      52964
# min      73522
# 25%     142051
# 50%     162382
# 75%     209261
# max     247905
# Name: yr_avg, dtype: float64

# %%
q_60 = metro_top20['yr_avg'].quantile(q=0.60)

# %%
print(f'Average Value 60% cutoff value: {round(q_60,2)}')
# Out:
# Average Value 60% cutoff value: 180323.85

# %%
q_35 = metro_top20['yr_avg'].quantile(q=0.35)

# %%
print(f'Average Value 35% cutoff value: {round(q_35,2)}')
# Out:
# Average Value 35% cutoff value: 153149.24

# %%
metro_top20
# Out:
#       RegionName  1/31/2000  2/29/2000  3/31/2000  4/30/2000  5/31/2000  \
# 1197       72204      55572      55559      55698      56096      56413
# 1266       72209      56903      57193      57297      57446      57766
# 1947       71901      62223      62575      62847      63484      64056
# 3107       72076      78447      78830      79165      79531      79919
# 3451       72032      84523      85280      85997      86508      86765
# 3592       72143      85512      85584      85830      86233      86478
# 4236       72205      97658      98280      98497      98798      99301
# 4898       72120     103008     103481     103695     104202     104740
# 5040       72764     100617     101055     101538     101932     102261
# 5066       71913      96315      96767      97553      98516      99481
# 5192       72701     107217     107618     108128     108986     109547
# 5633       72034     113666     114078     114408     114766     114768
# ...

# %%
top_pref= metro_top20[(metro_top20['yr_avg']<q_60) & (metro_top20['yr_avg']>q_35)]

# %%
top_pref
# Out:
#       RegionName  1/31/2000  2/29/2000  3/31/2000  4/30/2000  5/31/2000  \
# 4236       72205      97658      98280      98497      98798      99301
# 5040       72764     100617     101055     101538     101932     102261
# 5066       71913      96315      96767      97553      98516      99481
# 5633       72034     113666     114078     114408     114766     114768
# 5674       72023     113060     113329     113870     114300     114551
# 6045       72756      96855      96907      96970      97339      97438
#
#       6/30/2000  7/31/2000  8/31/2000  9/30/2000  10/31/2000  11/30/2000  \
# 4236      99916     100445     100833     101195      101589      102056
# 5040     102507     102992     103440     104070      104429      104897
# 5066     100163     100647     101029     101408      101749      102204
# 5633     114912     114966     115189     115464      115873      116493
# 5674     114714     114901     115250     115460      115833      116468
# ...

# %%
top_pref['ROI']= (top_pref['3/31/2020']/top_pref['1/31/2000'])-1
# Out:
# <ipython-input-649-e23b04f0a77d>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_pref['ROI']= (top_pref['3/31/2020']/top_pref['1/31/2000'])-1

# %%
top_pref['std']=top_pref.loc[:,'1/31/2000':'3/31/2020'].std(skipna=True, axis=1)
# Out:
# <ipython-input-650-89b10c90ff84>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_pref['std']=top_pref.loc[:,'1/31/2000':'3/31/2020'].std(skipna=True, axis=1)

# %%
top_pref['mean']=top_pref.loc[:,'1/31/2000':'3/31/2020'].mean(skipna=True, axis=1)
# Out:
# <ipython-input-651-7ca543db610c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_pref['mean']=top_pref.loc[:,'1/31/2000':'3/31/2020'].mean(skipna=True, axis=1)

# %%
top_pref['CV']=top_pref['std']/top_pref['mean']
# Out:
# <ipython-input-223-c31a1b01f8e4>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   top_pref['CV']=top_pref['std']/top_pref['mean']

# %%
df1 = pd.read_csv('https://raw.githubusercontent.com/2SUBDA/IST_718/master/Zip_Zhvi_SingleFamilyResidence_20.csv', on_bad_lines='skip')

# %%
df1['RegionName'] = df1['RegionName'].astype('str').apply(lambda x: x.zfill(5))

# %%
ardf = df1[df1['State'] == 'AR']

# %%
metroar1 = ardf.loc[ardf['Metro'].isin(['Searcy', 'Little Rock-North Little Rock-Conway', 'Fayetteville-Springdale-Rogers', 'Hot Springs'])]

# %%
metroar2018 = metroar1.drop(['1/31/2000', '2/29/2000', '3/31/2000', '4/30/2000', '5/31/2000', '6/30/2000', '7/31/2000', '8/31/2000', '9/30/2000', '10/31/2000', '11/30/2000', '12/31/2000', '1/31/2001',  '2/28/2001',  '3/31/2001',  '4/30/2001',  '5/31/2001',  '6/30/2001',  '7/31/2001',  '8/31/2001', '9/30/2001', '10/31/2001', '11/30/2001', '12/31/2001', '1/31/2002',  '2/28/2002',  '3/31/2002',  '4/30/2002',  '5/31/2002',  '6/30/2002',  '7/31/2002',  '8/31/2002',  '9/30/2002',  '10/31/2002', '11/30/2002', '12/31/2002', '1/31/2003',  '2/28/2003','3/31/2003', '4/30/2003', '5/31/2003',  '6/30/2003', '7/31/2003', '8/31/2003',  '9/30/2003',  '10/31/2003', '11/30/2003', '12/31/2003', '1/31/2004',  '2/29/2004',  '3/31/2004',  '4/30/2004', '5/31/2004', '6/30/2004',  '7/31/2004', '8/31/2004', '9/30/2004',  '10/31/2004', '11/30/2004', '12/31/2004', '1/31/2005',  '2/28/2005',  '3/31/2005',  '4/30/2005',  '5/31/2005',  '6/30/2005',  '7/31/2005',  '8/31/2005',  '9/30/2005',  '10/31/2005', '11/30/2005', '12/31/2005', '1/31/2006', '2/28/2006', '3/31/2006', '4/30/2006', '5/31/2006',  '6/30/2006', '7/31/2006', '8/31/2006', '9/30/2006', '10/31/2006', '11/30/2006', '12/31/2006', '1/31/2007',  '2/28/2007',  '3/31/2007',  '4/30/2007',  '5/31/2007', '6/30/2007', '7/31/2007', '8/31/2007', '9/30/2007', '10/31/2007', '11/30/2007', '12/31/2007', '1/31/2008', '2/29/2008', '3/31/2008', '4/30/2008', '5/31/2008', '6/30/2008', '7/31/2008', '8/31/2008', '9/30/2008', '10/31/2008', '11/30/2008', '12/31/2008', '1/31/2009', '2/28/2009', '3/31/2009', '4/30/2009', '5/31/2009', '6/30/2009', '7/31/2009', '8/31/2009', '9/30/2009', '10/31/2009', '11/30/2009', '12/31/2009', '1/31/2010', '2/28/2010', '3/31/2010', '4/30/2010', '5/31/2010', '6/30/2010', '7/31/2010', '8/31/2010', '9/30/2010', '10/31/2010', '11/30/2010', '12/31/2010', '1/31/2011',  '2/28/2011',  '3/31/2011',  '4/30/2011',  '5/31/2011',  '6/30/2011',  '7/31/2011',  '8/31/2011',  '9/30/2011', '10/31/2011',  '11/30/2011', '12/31/2011', '1/31/2012',  '2/29/2012',  '3/31/2012',  '4/30/2012',  '5/31/2012',  '6/30/2012',  '7/31/2012',  '8/31/2012',  '9/30/2012',  '10/31/2012', '11/30/2012', '12/31/2012', '1/31/2013', '2/28/2013', '3/31/2013', '4/30/2013', '5/31/2013', '6/30/2013', '7/31/2013', '8/31/2013', '9/30/2013', '10/31/2013', '11/30/2013', '12/31/2013', '1/31/2014', '2/28/2014', '3/31/2014', '4/30/2014', '5/31/2014', '6/30/2014', '7/31/2014', '8/31/2014', '9/30/2014', '10/31/2014', '11/30/2014', '12/31/2014', '1/31/2015', '2/28/2015', '3/31/2015',  '4/30/2015',  '5/31/2015',  '6/30/2015',  '7/31/2015',  '8/31/2015',  '9/30/2015',  '10/31/2015', '11/30/2015', '12/31/2015', '1/31/2016',  '2/29/2016',  '3/31/2016',  '4/30/2016',  '5/31/2016',  '6/30/2016',  '7/31/2016',  '8/31/2016',  '9/30/2016',  '10/31/2016',   '11/30/2016',   '12/31/2016',   '1/31/2017',  '2/28/2017',  '3/31/2017',  '4/30/2017',  '5/31/2017',  '6/30/2017',  '7/31/2017',  '8/31/2017',  '9/30/2017',  '10/31/2017', '11/30/2017', '12/31/2017', '1/31/2019', '2/28/2019',   '3/31/2019',  '4/30/2019',  '5/31/2019',  '6/30/2019',  '7/31/2019',  '8/31/2019',  '9/30/2019',  '10/31/2019', '11/30/2019', '12/31/2019', '1/31/2020', '2/29/2020', '3/31/2020', 'RegionID','RegionType','StateName','City','CountyName'], axis=1)

# %%
metroar2018.dropna(inplace=True)

# %%
metroar2018
# Out:
#        SizeRank RegionName State                                 Metro  \
# 61        30679      72139    AR                                Searcy
# 209        8043      72114    AR  Little Rock-North Little Rock-Conway
# 259       27759      72001    AR  Little Rock-North Little Rock-Conway
# 426       19004      72070    AR  Little Rock-North Little Rock-Conway
# 476        8519      72150    AR  Little Rock-North Little Rock-Conway
# ...         ...        ...   ...                                   ...
# 8735      13101      72732    AR        Fayetteville-Springdale-Rogers
# 9183      14554      72718    AR        Fayetteville-Springdale-Rogers
# 10408      8690      72212    AR  Little Rock-North Little Rock-Conway
# 10472     22038      72122    AR  Little Rock-North Little Rock-Conway
# 11857      4019      72223    AR  Little Rock-North Little Rock-Conway
#
#        1/31/2018  2/28/2018  3/31/2018  4/30/2018  5/31/2018  6/30/2018  \
# ...

# %%
print(metroar2018.SizeRank.describe(),'\n')
# Out:
# count      94
# mean    10749
# std      7466
# min       332
# 25%      4336
# 50%      9612
# 75%     14660
# max     30679
# Name: SizeRank, dtype: float64

# %%
sr_25 = metroar2018.SizeRank.quantile(q=0.25)
sr_25
# Out:
# 4335.5

# %%
zc_top25= metroar2018[metroar2018['SizeRank']<sr_25].drop(['State',
                                                       'SizeRank'],axis=1)

# %%
zc_top25
# Out:
#       RegionName                                 Metro  1/31/2018  2/28/2018  \
# 1197       72204  Little Rock-North Little Rock-Conway      69929      69402
# 1266       72209  Little Rock-North Little Rock-Conway      66865      67215
# 1947       71901                           Hot Springs     114698     115237
# 3107       72076  Little Rock-North Little Rock-Conway     102666     102914
# 3451       72032  Little Rock-North Little Rock-Conway     134447     134885
# 3592       72143                                Searcy     136673     136922
# 3602       72015  Little Rock-North Little Rock-Conway     124105     123914
# 4236       72205  Little Rock-North Little Rock-Conway     156476     157529
# 4898       72120  Little Rock-North Little Rock-Conway     146531     147054
# 5040       72764        Fayetteville-Springdale-Rogers     155569     157159
# 5066       71913                           Hot Springs     149326     149070
# ...

# %%
print(f'Amount of zipcodes: {len(zc_top25)}')
# Out:
# Amount of zipcodes: 24

# %%
zc_top25['yr_avg']=zc_top25.iloc[:,-12:].mean(skipna=True, axis=1)

# %%
print(zc_top25['yr_avg'].describe(),'\n')
# Out:
# count       24
# mean    171329
# std      58084
# min      69189
# 25%     137823
# 50%     166027
# 75%     203671
# max     335497
# Name: yr_avg, dtype: float64

# %%
q_60 = zc_top25['yr_avg'].quantile(q=0.60)

# %%
print(f'Average Value 60% cutoff value: {round(q_60,2)}')
# Out:
# Average Value 60% cutoff value: 185665.47

# %%
q_35 = zc_top25['yr_avg'].quantile(q=0.35)

# %%
print(f'Average Value 35% cutoff value: {round(q_35,2)}')
# Out:
# Average Value 35% cutoff value: 152047.38

# %%
zc_pref= zc_top25[(zc_top25['yr_avg']<q_60) & (zc_top25['yr_avg']>q_35)]

# %%
print(f'Amount of zipcodes: {len(zc_pref)}')
# Out:
# Amount of zipcodes: 5

# %%
zc_pref
# Out:
#      RegionName                                 Metro  1/31/2018  2/28/2018  \
# 4236      72205  Little Rock-North Little Rock-Conway     156476     157529
# 5040      72764        Fayetteville-Springdale-Rogers     155569     157159
# 5633      72034  Little Rock-North Little Rock-Conway     173115     173578
# 5674      72023  Little Rock-North Little Rock-Conway     150744     150861
# 6045      72756        Fayetteville-Springdale-Rogers     164381     166291
#
#       3/31/2018  4/30/2018  5/31/2018  6/30/2018  7/31/2018  8/31/2018  \
# 4236     157716     157768     157781     158197     158719     159057
# 5040     158398     159571     160392     161633     162404     162893
# 5633     174113     174864     175597     176041     176604     177103
# 5674     151117     151422     151849     152317     152738     153192
# 6045     167760     169676     170985     171861     171696     171614
#
#       9/30/2018  10/31/2018  11/30/2018  12/31/2018  yr_avg
# ...

# %%
zc_pref['std']=zc_pref.loc[:,'1/31/2018':'12/31/2018'].std(skipna=True, axis=1)
zc_pref['mean']=zc_pref.loc[:,'1/31/2018':'12/31/2018'].mean(skipna=True, axis=1)
zc_pref['CV']=zc_pref['mean']/zc_pref['std']
zc_pref[['RegionName','std','mean','CV']].head()
# Out:
# <ipython-input-473-cc15f85f78a5>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zc_pref['std']=zc_pref.loc[:,'1/31/2018':'12/31/2018'].std(skipna=True, axis=1)
# <ipython-input-473-cc15f85f78a5>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   zc_pref['mean']=zc_pref.loc[:,'1/31/2018':'12/31/2018'].mean(skipna=True, axis=1)
# <ipython-input-473-cc15f85f78a5>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# ...

# %%
print(zc_pref.CV.describe())
# Out:
# count     5
# mean     77
# std      24
# min      50
# 25%      55
# 50%      85
# 75%      86
# max     108
# Name: CV, dtype: float64

# %%
upper_cv = zc_pref.CV.quantile(.6)

# %%
print(f'\nCV upper limit: {upper_cv}')
# Out:
# CV upper limit: 85.35908396067296

# %%
zc_best3 = zc_pref[zc_pref['CV']<upper_cv].sort_values('ROI',axis=0,ascending=False)[:3]

# %%
zc_best3
# Out:
#      RegionName                                 Metro  1/31/2018  2/28/2018  \
# 5040      72764        Fayetteville-Springdale-Rogers     155569     157159
# 6045      72756        Fayetteville-Springdale-Rogers     164381     166291
# 5633      72034  Little Rock-North Little Rock-Conway     173115     173578
#
#       3/31/2018  4/30/2018  5/31/2018  6/30/2018  7/31/2018  8/31/2018  \
# 5040     158398     159571     160392     161633     162404     162893
# 6045     167760     169676     170985     171861     171696     171614
# 5633     174113     174864     175597     176041     176604     177103
#
#       9/30/2018  10/31/2018  11/30/2018  12/31/2018  yr_avg  std   mean  CV  \
# 5040     163261      164059      165031      165919  161357 3202 161357  50
# 6045     172220      173250      174028      174597  170697 3125 170697  55
# 5633     177811      178324      178867      179303  176277 2082 176277  85
#
#       ROI
# 5040    0
# 6045    0
# 5633    0

# %%
zc_best3[['RegionName', 'Metro','std','CV']]
# Out:
#      RegionName                                 Metro  std  CV
# 5040      72764        Fayetteville-Springdale-Rogers 3202  50
# 6045      72756        Fayetteville-Springdale-Rogers 3125  55
# 5633      72034  Little Rock-North Little Rock-Conway 2082  85

# %%
keep_cols = ['RegionName', 'Metro']

# %%
Dates2018 = ['1/31/2018',	'2/28/2018','3/31/2018','4/30/2018', '5/31/2018',	'6/30/2018','7/31/2018','8/31/2018','9/30/2018','10/31/2018',	'11/30/2018',	'12/31/2018']

# %%
meltedf3 = pd.melt(frame=zc_best3, id_vars=keep_cols, value_vars=Dates2018, var_name='YearMonth', value_name='HousePrice')

# %%
meltedf3
# Out:
#    RegionName                                 Metro   YearMonth  HousePrice
# 0       72764        Fayetteville-Springdale-Rogers   1/31/2018      155569
# 1       72756        Fayetteville-Springdale-Rogers   1/31/2018      164381
# 2       72034  Little Rock-North Little Rock-Conway   1/31/2018      173115
# 3       72764        Fayetteville-Springdale-Rogers   2/28/2018      157159
# 4       72756        Fayetteville-Springdale-Rogers   2/28/2018      166291
# 5       72034  Little Rock-North Little Rock-Conway   2/28/2018      173578
# 6       72764        Fayetteville-Springdale-Rogers   3/31/2018      158398
# 7       72756        Fayetteville-Springdale-Rogers   3/31/2018      167760
# 8       72034  Little Rock-North Little Rock-Conway   3/31/2018      174113
# 9       72764        Fayetteville-Springdale-Rogers   4/30/2018      159571
# 10      72756        Fayetteville-Springdale-Rogers   4/30/2018      169676
# ...

# %%
meltedf3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36 entries, 0 to 35
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   RegionName  36 non-null     object
#  1   Metro       36 non-null     object
#  2   YearMonth   36 non-null     object
#  3   HousePrice  36 non-null     int64
# dtypes: int64(1), object(3)
# memory usage: 1.2+ KB

# %%
metro_grp = meltedf3.groupby('Metro')

# %%
metro_grp = meltedf3.HousePrice.mean()

# %%
metro_grp
# Out:
# 169443.55555555556

# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',0)

# %%
plt.style.use('seaborn-notebook')

# %%
zipcode_list = meltedf['RegionName'].unique().tolist()

# %%
def plot_df(metro_grp, x, y, title="", xlabel='MonthYear', ylabel='HousePrice', dpi=100):
    plt.figure(figsize=(15,4), dpi=dpi)
    plt.plot(x, y, color='tab:red')
    plt.gca().set(title=title, xlabel=xlabel, ylabel=ylabel)
    plt.show()
    plot_df(metro_grp, x=metro_grp['MonthYear'], y=metro_grp['HousePrice'], title='AR')
